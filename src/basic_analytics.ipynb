# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv('model_results.csv', index_col=0)

# %%
df.head()
# Out:
#                          timestamp  accuracy  precision    recall  f1_score  \
# model_name
# RoBERTaModel   2025-03-29 17:43:25  0.833333   0.694444  0.833333  0.757576
# RoBERTaModel   2025-03-29 19:25:32  0.783000   0.789617  0.783000  0.782986
# RoBERTaModel   2025-03-29 18:22:21  0.750000   0.562500  0.750000  0.642857
# EnhancedModel  2025-03-29 17:58:04  0.711500   0.702052  0.764078  0.731753
# RoBERTaModel   2025-03-29 17:45:37  0.700000   0.675000  0.700000  0.680000
#
#                param_C param_batch_normalization  param_batch_size  \
# model_name
# RoBERTaModel       NaN                       NaN              16.0
# RoBERTaModel       NaN                       NaN              16.0
# RoBERTaModel       NaN                       NaN              16.0
# EnhancedModel      NaN                      True              32.0
# RoBERTaModel       NaN                       NaN              16.0
#
#                         param_dropout_rates  param_epochs  ...  \
# ...
